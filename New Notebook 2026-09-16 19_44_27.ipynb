# %%
# %sql
CREATE OR REPLACE TABLE workspace.default.bronze_feature_tbl AS
SELECT
  monotonically_increasing_id() AS id,
  *
FROM
  workspace.default.bronze_features;




-- Set ID not nullable and set as primary key
ALTER TABLE
  workspace.default.bronze_feature_tbl
ALTER COLUMN
  id
  SET NOT NULL;

ALTER TABLE
  workspace.default.bronze_feature_tbl
ADD
  CONSTRAINT pk_bronze PRIMARY KEY (id);
