# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
    'Age': [25, 30, 22, 35, 28],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix'],
    'Occupation': ['Engineer', 'Artist', 'Teacher', 'Chef', 'Designer'],
    'Score': [88, 92, 79, 85, 90]
})

df.to_csv('test_csv.csv', index=False)
